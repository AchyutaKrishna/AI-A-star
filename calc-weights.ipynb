# %%
import pandas as pd
import requests
import json
import urllib.request

# %%
d1 = pd.read_csv('edge.csv')
d1
# Out:
#       Source           Destination
# 0       RGIA              Gangaram
# 1       RGIA             Kurmaguda
# 2       RGIA  Rajendranagar Mandal
# 3       RGIA             Kismatpur
# 4   Gangaram             Kurmaguda
# ..       ...                   ...
# 63     Alwal        BITS Hyderabad
# 64     Alwal               Bolarum
# 65   Bolarum        BITS Hyderabad
# 66   Bolarum               Medchal
# 67   Medchal        BITS Hyderabad
#
# [68 rows x 2 columns]

# %%
d2 = pd.read_csv('place.csv')
d2
# Out:
#               Localities
# 0              Kurmaguda
# 1   Rajendranagar Mandal
# 2              Kismatpur
# 3           Sivarampalli
# 4                Attapur
# 5       Kothapet Village
# 6              Manikonda
# 7          Banjara Hills
# 8          Jubilee Hills
# 9            Khairatabad
# 10              Ameerpet
# 11            Malkajgiri
# 12             L B Nagar
# 13              Gangaram
# 14              Pocharam
# 15                Nagole
# 16                 Uppal
# 17            Hitec City
# 18             Balanagar
# 19            Kukatpally
# 20          Trimulgherry
# 21             Moula Ali
# 22                 Alwal
# 23             Old Alwal
# 24               Bolarum
# 25                Yapral
# 26            Sainikpuri
# 27                 Kapra
# 28            Dammaiguda
# 29                 Daira
# 30            Gachibowli
# 31               Bakaram
# 32              Kondapur
# 33          Chanda Nagar
# 34               Miyapur
# 35            Bachupally
# ...

# %%
d3 = pd.read_csv('lat-long.csv')
d3 = d3.drop('Unnamed: 0', axis=1)
d3
# Out:
#               Localities   latitude  longitude
# 0              Kurmaguda  17.360771  78.502404
# 1   Rajendranagar Mandal  17.361597  78.427675
# 2              Kismatpur  17.334436  78.385025
# 3           Sivarampalli  17.322384  78.430635
# 4                Attapur  17.367224  78.430728
# 5       Kothapet Village  17.374043  78.543613
# 6              Manikonda  17.399995  78.386169
# 7          Banjara Hills  17.417746  78.439901
# 8          Jubilee Hills  17.430836  78.410288
# 9            Khairatabad  17.411771  78.462200
# 10              Ameerpet  17.437501  78.448251
# 11            Malkajgiri  17.451176  78.536900
# 12             L B Nagar  17.349846  78.547941
# 13              Gangaram  17.494335  78.329569
# 14              Pocharam  17.436614  78.642224
# 15                Nagole  17.377531  78.560123
# 16                 Uppal  17.402509  78.561256
# 17            Hitec City  17.449005  78.383138
# 18             Balanagar  17.476746  78.422108
# ...

# %%
def distance(s_lat, s_long, d_lat, d_long):
    api_key = 'AIzaSyBv8NyZ4VhYSOfQuQcXOpRthwRWHOzCDOY'
    url ='https://maps.googleapis.com/maps/api/distancematrix/json?'
    source = str(s_lat)+','+str(s_long)
    dest = str(d_lat)+','+str(d_long)
    r = requests.get(url + 'origins = ' + source + '&destinations = ' + dest + '&key = ' + api_key)
    x = r.json()
    #duration = x['rows'][0]['elements'][0]['duration']['value']
    #duration = float(duration/60)
    #return duration
    print(x)

# %%
coord = {}

for i in range(len(d3['Localities'])):
    key = d2['Localities'][i]
    coord[key] = (float(d3['latitude'][i]), float(d3['longitude'][i]))

# %%
d1['Distance'] = d1['Source']

for i in range(len(d1['Source'])):
    c1 = d1['Source'][i]
    c2 = d1['Destination'][i]
    d1['Distance'] = distance(coord[c1][0], coord[c1][1], coord[c2][0], coord[c2][1])
# Out:
# {'destination_addresses': [], 'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}
# {'destination_addresses': [], 'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}
# {'destination_addresses': [], 'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}
# ...

# %%
# Out:
#       Source           Destination  Distance
# 0       RGIA              Gangaram         0
# 1       RGIA             Kurmaguda         0
# 2       RGIA  Rajendranagar Mandal         0
# 3       RGIA             Kismatpur         0
# 4   Gangaram             Kurmaguda         0
# ..       ...                   ...       ...
# 63     Alwal        BITS Hyderabad         0
# 64     Alwal               Bolarum         0
# 65   Bolarum        BITS Hyderabad         0
# 66   Bolarum               Medchal         0
# 67   Medchal        BITS Hyderabad         0
#
# [68 rows x 3 columns]

# %%
distance(17.360771, 78.502404, 17.494335 ,78.329569)
# Out:
# {'destination_addresses': [], 'error_message': 'You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}

# %%
def dist(src_lat, src_lng, dest_lat, dest_lng):
    endpoint = 'https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&'
    api_key = 'AIzaSyDLaeAPrH7JqYZbn1wsaG55xfqHLlI_Q6Q'
    nav_request = 'origins={}&destinations={}&key={}'.format(str(src_lat)+','+str(src_lng),str(dest_lat)+','+str(dest_lng),api_key)
    request = endpoint + nav_request
    response = urllib.request.urlopen(request).read()
    duration = json.loads(response)
    print(duration)
    #duration = duration['rows'][0]['elements'][0]['duration']['value']
    #duration = float(duration/60)
    #return duration

# %%
dist(17.360771, 78.502404, 17.494335 ,78.329569)
# Out:
# {'destination_addresses': [], 'error_message': 'This API project was not found. This API project may have been deleted or may not be authorized to use this API. You may need to enable the API under APIs in the console.', 'origin_addresses': [], 'rows': [], 'status': 'REQUEST_DENIED'}
